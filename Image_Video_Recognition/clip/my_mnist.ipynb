# %%
from matplotlib import pyplot as plt
from IPython import display
# %matplotlib inline
display.set_matplotlib_formats('svg')

# %%
plt.figure(figsize=(10,5))
plt.subplot(2, 4, 1)
plt.xticks([])
plt.yticks([])
plt.subplot(2, 4, 2)
# plt.axis('off')
plt.xticks([])
plt.yticks([])
plt.subplot(2, 4, 5)
plt.xticks([])
plt.yticks([])
plt.show()
plt.savefig('./test.jpg')

# %%
# !pip install opencv-python
# Out:
# ...
#      |████████████████████████████████| 52.4MB 21.6MB/s eta 0:00:01    |██████████████████████████████  | 49.0MB 6.4MB/s eta 0:00:01
# ...

# %%
import cv2
I = cv2.imread('./test.jpg')

# %%
import numpy as np
np.unique(I)
# Out:
# array([255], dtype=uint8)

# %%
import matplotlib.patches as patches
rect = plt.Rectangle((0.2,0.75), 0.4, 0.15, color = 'r', alpha = 0.3)#左下起点，长，宽，颜色，α
rect=patches.Rectangle((200, 600),550,650,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-fc1e5bdf094e> in <module>
#       2 rect = plt.Rectangle((0.2,0.75), 0.4, 0.15, color = 'r', alpha = 0.3)#左下起点，长，宽，颜色，α
#       3 rect=patches.Rectangle((200, 600),550,650,linewidth=1,edgecolor='r',facecolor='none')
# ----> 4 ax.add_patch(rect)
#
# NameError: name 'ax' is not defined

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import cv2

img=cv2.imread("./result.png")
plt.figure(8)
plt.imshow(img)
currentAxis=plt.gca()
rect=patches.Rectangle((200, 600),550,650,linewidth=1,edgecolor='r',facecolor='none')
currentAxis.add_patch(rect)
plt.savefig('./test2.png')

# %%
# plt.figure(figsize=(200,200))
ax = plt.subplot(331)
# ax.axis([0,5,0,5])
plt.axis('off')
# ax.add_patch(patches.Rectangle((0, 0), 2.56, 2.56))
# ax.add_patch(patches.Rectangle((3, 3), 2.56, 2.56))
rect = patches.Rectangle((50,100),40,30,linewidth=1,edgecolor='r',facecolor='none')
ax.add_patch(rect)
